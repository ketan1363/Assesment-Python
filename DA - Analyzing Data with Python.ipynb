# %%
import numpy as np
import pandas as pd

# %%
ipl_df = pd.read_csv("/Users/jeelvaghani/Desktop/tops /python ipl analysis/matches - matches.csv")

# %%
ipl_df
# Out:
#       id  season       city        date                        team1  \
# 0    1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2    3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3    4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4    5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 994  NaN     NaN        NaN         NaN                          NaN
# 995  NaN     NaN        NaN         NaN                          NaN
# 996  NaN     NaN        NaN         NaN                          NaN
# 997  NaN     NaN        NaN         NaN                          NaN
# 998  NaN     NaN        NaN         NaN                          NaN
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl_df.head(10)
# Out:
#      id  season       city        date                        team1  \
# 0   1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2   3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3   4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4   5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6.0  2017.0  Hyderabad  2017-04-09                Gujarat Lions
# 6   7.0  2017.0     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8.0  2017.0     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9.0  2017.0       Pune  2017-04-11             Delhi Daredevils
# 9  10.0  2017.0     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
ipl_df.head() ## preview your top raws
# Out:
#     id  season       city        date                        team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1  2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2  3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3  4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4  5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_df.head(3)
# Out:
#     id  season       city        date                team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1  2.0  2017.0       Pune  2017-04-06       Mumbai Indians
# 2  3.0  2017.0     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal         0.0     Sunrisers Hyderabad         35.0             0.0
# 1  normal         0.0  Rising Pune Supergiant          0.0             7.0
# 2  normal         0.0   Kolkata Knight Riders          0.0            10.0
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
ipl_df.tail(2)
# Out:
#      id  season city date team1 team2 toss_winner toss_decision result  \
# 997 NaN     NaN  NaN  NaN   NaN   NaN         NaN           NaN    NaN
# 998 NaN     NaN  NaN  NaN   NaN   NaN         NaN           NaN    NaN
#
#      dl_applied winner  win_by_runs  win_by_wickets player_of_match venue  \
# 997         NaN    NaN          NaN             NaN             NaN   NaN
# 998         NaN    NaN          NaN             NaN             NaN   NaN
#
#     umpire1 umpire2  umpire3
# 997     NaN     NaN      NaN
# 998     NaN     NaN      NaN

# %%
ipl_df.shape # it's shows the no. of raws and columm.
# Out:
# (999, 18)

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    float64
#  1   season           636 non-null    float64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    float64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    float64
#  12  win_by_wickets   636 non-null    float64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
# ...

# %%
ipl_df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
ipl_df.head(1)
# Out:
#     id  season       city        date                team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal         0.0  Sunrisers Hyderabad         35.0             0.0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
ipl_df["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 994                            NaN
# 995                            NaN
# 996                            NaN
# 997                            NaN
# 998                            NaN
# Name: winner, Length: 999, dtype: object

# %%
ipl_df["winner"].shape
# Out:
# (999,)

# %%
ipl_df[["team1","team2","winner"]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 994                          NaN                          NaN
# 995                          NaN                          NaN
# 996                          NaN                          NaN
# 997                          NaN                          NaN
# 998                          NaN                          NaN
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
ipl_df.iloc[0]
# Out:
# id                                                       1.0
# season                                                2017.0
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                               0.0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                             35.0
# win_by_wickets                                           0.0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
ipl_df.iloc[0:5]
# Out:
#     id  season       city        date                        team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1  2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2  3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3  4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4  5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_df.iloc[0:5].shape
# Out:
# (5, 18)

# %%
ipl_df.iloc[1:11:4]
# Out:
#      id  season       city        date                team1  \
# 1   2.0  2017.0       Pune  2017-04-06       Mumbai Indians
# 5   6.0  2017.0  Hyderabad  2017-04-09        Gujarat Lions
# 9  10.0  2017.0     Mumbai  2017-04-12  Sunrisers Hyderabad
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 9          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1         0.0  Rising Pune Supergiant          0.0             7.0
# 5         0.0     Sunrisers Hyderabad          0.0             9.0
# 9         0.0          Mumbai Indians          0.0             4.0
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
ipl_df.iloc[[2,4,8]] # fancy indexing
# Out:
#     id  season       city        date                        team1  \
# 2  3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 4  5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8  9.0  2017.0       Pune  2017-04-11             Delhi Daredevils
#
#                     team2                  toss_winner toss_decision  result  \
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 8  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 2         0.0        Kolkata Knight Riders          0.0            10.0
# 4         0.0  Royal Challengers Bangalore         15.0             0.0
# 8         0.0             Delhi Daredevils         97.0             0.0
#
#   player_of_match                                    venue      umpire1  \
# ...

# %%
ipl_df.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 994                          NaN                          NaN
# 995                          NaN                          NaN
# 996                          NaN                          NaN
# 997                          NaN                          NaN
# 998                          NaN                          NaN
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
ipl_df.iloc[[1,3],[4,5,10]]
# Out:
#                     team1                   team2                  winner
# 1          Mumbai Indians  Rising Pune Supergiant  Rising Pune Supergiant
# 3  Rising Pune Supergiant         Kings XI Punjab         Kings XI Punjab

# %%
mask=ipl_df["city"]=="Hyderabad"

# %%
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# Name: city, Length: 999, dtype: bool

# %%
ipl1=ipl_df[mask] ## gives the data frame
ipl1.head()
# Out:
#       id  season       city        date                team1  \
# 0    1.0  2017.0  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 5    6.0  2017.0  Hyderabad  2017-04-09        Gujarat Lions
# 18  19.0  2017.0  Hyderabad  2017-04-17  Sunrisers Hyderabad
# 20  21.0  2017.0  Hyderabad  2017-04-19  Sunrisers Hyderabad
# 35  36.0  2017.0  Hyderabad  2017-04-30  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# 35        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#     result  dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
ipl1.shape
# Out:
# (49, 18)

# %%
def get_city(city):
    mask=ipl_df["city"]==city
    return ipl_df[mask]

# %%
get_city("Hyderabad")
# Out:
#         id  season       city        date                        team1  \
# 0      1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6.0  2017.0  Hyderabad  2017-04-09                Gujarat Lions
# 18    19.0  2017.0  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21.0  2017.0  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36.0  2017.0  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43.0  2017.0  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47.0  2017.0  Hyderabad  2017-05-08               Mumbai Indians
# 58    59.0  2017.0  Hyderabad  2017-05-21               Mumbai Indians
# 65    66.0  2008.0  Hyderabad  2008-04-22              Deccan Chargers
# 67    68.0  2008.0  Hyderabad  2008-04-24              Deccan Chargers
# 76    77.0  2008.0  Hyderabad  2008-05-01              Deccan Chargers
# 79    80.0  2008.0  Hyderabad  2008-05-25              Deccan Chargers
# ...

# %%
def get_city_count(city):
    mask=ipl_df["city"]==city
    return ipl_df[mask].shape

# %%
get_city_count("Hyderabad")
# Out:
# (49, 18)

# %%
mask1=ipl_df["city"]=="Hyderabad"
mask2=ipl_df["date"]>"01-01-2020"
ipl_df[mask1 & mask2].shape
# Out:
# (49, 18)

# %%
ipl_df[mask1 & mask2].head()
# Out:
#       id  season       city        date                team1  \
# 0    1.0  2017.0  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 5    6.0  2017.0  Hyderabad  2017-04-09        Gujarat Lions
# 18  19.0  2017.0  Hyderabad  2017-04-17  Sunrisers Hyderabad
# 20  21.0  2017.0  Hyderabad  2017-04-19  Sunrisers Hyderabad
# 35  36.0  2017.0  Hyderabad  2017-04-30  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# 35        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#     result  dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
ipl_df[mask1 | mask2].shape
# Out:
# (636, 18)

# %%
ipl_df["winner"].value_counts().sort_values(ascending=False).head(4)
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Name: count, dtype: int64

# %%
ipl_df["winner"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='winner'>

# %%
ipl_df["winner"].value_counts().sort_values(ascending=False).head(4).plot(kind="bar")
# Out:
# <Axes: xlabel='winner'>

# %%
ipl_df["winner"].value_counts().sort_values(ascending=False).head(4).plot(kind="barh")
# Out:
# <Axes: ylabel='winner'>

# %%
ipl_df.head()
# Out:
#     id  season       city        date                        team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1  2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2  3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3  4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4  5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_df["toss_decision"].value_counts()
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
ipl_df["toss_decision"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
ipl_df["win_by_runs"].plot(kind = "hist") ## histogram works on numeric value
# Out:
# <Axes: ylabel='Frequency'>

# %%
ipl_df["win_by_wickets"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
ipl_df["win_by_wickets"].plot(kind = "pie")
# Out:
# <Axes: ylabel='win_by_wickets'>

# %%
ipl_df["win_by_wickets"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
myseries = ipl_df["winner"].value_counts()

# %%
myseries
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
myseries.head()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: count, dtype: int64

# %%
myseries["Kochi Tuskers Kerala"]
# Out:
# 6

# %%
ipl_df["team1"].value_counts() + ipl_df["team2"].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
(ipl_df["team1"].value_counts() + ipl_df["team2"].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
(ipl_df["team1"].value_counts() + ipl_df["team2"].value_counts()).sort_values(ascending=False).head()
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Name: count, dtype: int64

# %%
(ipl_df["team1"].value_counts() + ipl_df["team2"].value_counts()).sort_values(ascending=False).head().plot(title = "Total Matches Played by Team" ,xlabel="Team Name",ylabel = "Total Matches Played",kind= "bar",color = "Magenta")
# Out:
# <Axes: title={'center': 'Total Matches Played by Team'}, xlabel='Team Name', ylabel='Total Matches Played'>

# %%
ipl_df.sort_values("city",ascending=False)
# Out:
#         id  season           city        date                team1  \
# 312  313.0  2012.0  Visakhapatnam  2012-04-07  Chennai Super Kings
# 622  623.0  2016.0  Visakhapatnam  2016-05-15       Mumbai Indians
# 615  616.0  2016.0  Visakhapatnam  2016-05-10  Sunrisers Hyderabad
# 612  613.0  2016.0  Visakhapatnam  2016-05-08  Sunrisers Hyderabad
# 624  625.0  2016.0  Visakhapatnam  2016-05-17     Delhi Daredevils
# ..     ...     ...            ...         ...                  ...
# 994    NaN     NaN            NaN         NaN                  NaN
# 995    NaN     NaN            NaN         NaN                  NaN
# 996    NaN     NaN            NaN         NaN                  NaN
# 997    NaN     NaN            NaN         NaN                  NaN
# 998    NaN     NaN            NaN         NaN                  NaN
#
#                        team2              toss_winner toss_decision  result  \
# 312          Deccan Chargers          Deccan Chargers         field  normal
# ...

# %%
ipl_df.sort_values(["city","date"],ascending=False)
# Out:
#         id  season           city        date                team1  \
# 628  629.0  2016.0  Visakhapatnam  2016-05-21      Kings XI Punjab
# 624  625.0  2016.0  Visakhapatnam  2016-05-17     Delhi Daredevils
# 622  623.0  2016.0  Visakhapatnam  2016-05-15       Mumbai Indians
# 618  619.0  2016.0  Visakhapatnam  2016-05-13       Mumbai Indians
# 615  616.0  2016.0  Visakhapatnam  2016-05-10  Sunrisers Hyderabad
# ..     ...     ...            ...         ...                  ...
# 994    NaN     NaN            NaN         NaN                  NaN
# 995    NaN     NaN            NaN         NaN                  NaN
# 996    NaN     NaN            NaN         NaN                  NaN
# 997    NaN     NaN            NaN         NaN                  NaN
# 998    NaN     NaN            NaN         NaN                  NaN
#
#                        team2              toss_winner toss_decision  result  \
# 628  Rising Pune Supergiants          Kings XI Punjab           bat  normal
# ...

# %%
ipl_df.sort_values(["city","date"],ascending=[True,False]).head(10)
# Out:
#         id  season       city        date                        team1  \
# 475  476.0  2014.0  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471.0  2014.0  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472.0  2014.0  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465.0  2014.0  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460.0  2014.0  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461.0  2014.0  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 457  458.0  2014.0  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 539  540.0  2015.0  Ahmedabad  2015-04-24             Rajasthan Royals
# 535  536.0  2015.0  Ahmedabad  2015-04-21             Rajasthan Royals
# 532  533.0  2015.0  Ahmedabad  2015-04-19          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 475        Kolkata Knight Riders             Rajasthan Royals           bat
# ...

# %%
ipl_df.drop_duplicates(subset=["team1"]).shape
# Out:
# (15, 18)

# %%
ipl_df.drop_duplicates(subset="season",keep="last")[["season","winner"]].sort_values("season")
# Out:
#      season                 winner
# 116  2008.0       Rajasthan Royals
# 173  2009.0        Deccan Chargers
# 233  2010.0    Chennai Super Kings
# 306  2011.0    Chennai Super Kings
# 380  2012.0  Kolkata Knight Riders
# 456  2013.0         Mumbai Indians
# 516  2014.0  Kolkata Knight Riders
# 575  2015.0         Mumbai Indians
# 635  2016.0    Sunrisers Hyderabad
# 58   2017.0         Mumbai Indians
# 998     NaN                    NaN

# %%
d_df = pd.read_csv("/Users/jeelvaghani/Desktop/tops /python ipl analysis/deliveries.csv")

# %%
d_df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
d_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
d_df.tail()
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 150455       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150456       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150457       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150458       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150459       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
#         over  ball        batsman    non_striker   bowler  is_super_over  ...  \
# 150455    20     2    Sachin Baby      CJ Jordan  B Kumar              0  ...
# 150456    20     3    Sachin Baby      CJ Jordan  B Kumar              0  ...
# 150457    20     4  Iqbal Abdulla    Sachin Baby  B Kumar              0  ...
# 150458    20     5    Sachin Baby  Iqbal Abdulla  B Kumar              0  ...
# 150459    20     6  Iqbal Abdulla    Sachin Baby  B Kumar              0  ...
#
# ...

# %%
d_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150460 non-null  int64
#  1   inning            150460 non-null  int64
#  2   batting_team      150460 non-null  object
#  3   bowling_team      150460 non-null  object
#  4   over              150460 non-null  int64
#  5   ball              150460 non-null  int64
#  6   batsman           150460 non-null  object
#  7   non_striker       150460 non-null  object
#  8   bowler            150460 non-null  object
#  9   is_super_over     150460 non-null  int64
#  10  wide_runs         150460 non-null  int64
#  11  bye_runs          150460 non-null  int64
#  12  legbye_runs       150460 non-null  int64
#  13  noball_runs       150460 non-null  int64
#  14  penalty_runs      150460 non-null  int64
#  15  batsman_runs      150460 non-null  int64
# ...

# %%
d_df.shape
# Out:
# (150460, 21)

# %%
run = d_df.groupby("batsman")

# %%
run

# %%
run["batsman_runs"].sum().sort_values(ascending=False).head()
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %%
run["batsman_runs"].sum().sort_values(ascending=True).head(3)
# Out:
# batsman
# S Kaushik         0
# S Ladda           0
# V Pratap Singh    0
# Name: batsman_runs, dtype: int64

# %%
d_df["batsman_runs"]
# Out:
# 0         0
# 1         0
# 2         4
# 3         0
# 4         0
#          ..
# 150455    2
# 150456    0
# 150457    0
# 150458    1
# 150459    4
# Name: batsman_runs, Length: 150460, dtype: int64

# %%
mask = d_df["batsman_runs"]==4
mask
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459     True
# Name: batsman_runs, Length: 150460, dtype: bool

# %%
ND = d_df[mask]

# %%
ND
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150403       636       2  Royal Challengers Bangalore
# 150407       636       2  Royal Challengers Bangalore
# 150418       636       2  Royal Challengers Bangalore
# 150447       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman  \
# 2       Royal Challengers Bangalore     1     3      DA Warner
# 8       Royal Challengers Bangalore     2     2      DA Warner
# 13      Royal Challengers Bangalore     2     7   MC Henriques
# ...

# %%
ND.groupby("batsman")["batsman_runs"].sum().sort_values(ascending=False).head()
# Out:
# batsman
# G Gambhir    1936
# SK Raina     1608
# DA Warner    1604
# S Dhawan     1604
# V Kohli      1536
# Name: batsman_runs, dtype: int64

# %%
mask2=d_df["batsman"]=="V Kohli"
ND2=d_df[mask2]

# %%
ND2
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
ND2.groupby("bowling_team")["batsman_runs"].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %%
ND2.groupby(["bowling_team","non_striker"])["batsman_runs"].sum().sort_values(ascending=False)
# Out:
# bowling_team           non_striker
# Kings XI Punjab        CH Gayle          251
# Delhi Daredevils       CH Gayle          205
#                        AB de Villiers    184
# Sunrisers Hyderabad    AB de Villiers    159
# Kolkata Knight Riders  CH Gayle          158
#                                         ...
# Chennai Super Kings    RR Bhatkal          0
# Kolkata Knight Riders  PA Patel            0
# Rajasthan Royals       PA Patel            0
# Chennai Super Kings    VH Zol              0
# Mumbai Indians         R Dravid            0
# Name: batsman_runs, Length: 164, dtype: int64

# %%
def highest_runs(batsman):
    mask2 = d_df["batsman"]==batsman
    ND2 = d_df[mask2]
    return ND2.groupby("bowling_team")["batsman_runs"].sum().sort_values(ascending=False).head(1)

# %%
highest_runs("V Kohli")
# Out:
# bowling_team
# Chennai Super Kings    706
# Name: batsman_runs, dtype: int64

# %%
DO = d_df[d_df["over"]>15]
DO
# Out:
#         match_id  inning                 batting_team  \
# 93             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 95             1       1          Sunrisers Hyderabad
# 96             1       1          Sunrisers Hyderabad
# 97             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 93      Royal Challengers Bangalore    16     1   MC Henriques   Yuvraj Singh
# 94      Royal Challengers Bangalore    16     2   MC Henriques   Yuvraj Singh
# 95      Royal Challengers Bangalore    16     3   Yuvraj Singh       DJ Hooda
# ...

# %%
DO.groupby("batsman")["batsman_runs"].count()>200
# Out:
# batsman
# A Ashish Reddy    False
# A Chandila        False
# A Chopra          False
# A Choudhary       False
# A Flintoff        False
#                   ...
# YS Chahal         False
# YV Takawale       False
# Yashpal Singh     False
# Yuvraj Singh       True
# Z Khan            False
# Name: batsman_runs, Length: 416, dtype: bool

# %%
all_batsman =DO.groupby("batsman")["batsman_runs"].count()
y =all_batsman>200
y
# Out:
# batsman
# A Ashish Reddy    False
# A Chandila        False
# A Chopra          False
# A Choudhary       False
# A Flintoff        False
#                   ...
# YS Chahal         False
# YV Takawale       False
# Yashpal Singh     False
# Yuvraj Singh       True
# Z Khan            False
# Name: batsman_runs, Length: 416, dtype: bool

# %%
bats_manlist = all_batsman[y].index.tolist()
bats_manlist
# Out:
# ['A Mishra',
#  'AB de Villiers',
#  'AD Mathews',
#  'AM Rahane',
#  'AR Patel',
#  'AT Rayudu',
#  'BJ Hodge',
#  'DA Miller',
#  'DA Warner',
#  'DJ Bravo',
#  'DJ Hussey',
#  'DPMD Jayawardene',
#  'Harbhajan Singh',
#  'IK Pathan',
#  'JA Morkel',
#  'JH Kallis',
#  'JP Duminy',
#  'JP Faulkner',
#  'KA Pollard',
#  'KD Karthik',
#  'KM Jadhav',
#  'LRPL Taylor',
#  'MK Pandey',
#  'MK Tiwary',
#  'MS Dhoni',
#  'NV Ojha',
#  'P Kumar',
#  'PP Chawla',
#  'R Vinay Kumar',
#  'RA Jadeja',
#  'RG Sharma',
#  'RV Uthappa',
#  'S Badrinath',
#  'S Dhawan',
#  'SK Raina',
#  'SPD Smith',
#  'SS Tiwary',
#  'STR Binny',
#  'V Kohli',
#  'WP Saha',
#  'Y Venugopal Rao',
#  'YK Pathan',
#  'Yuvraj Singh']
